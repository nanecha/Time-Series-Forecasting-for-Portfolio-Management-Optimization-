# %% [markdown]
# # Task 2: Time Series Forecasting for TSLA
# - This notebook implements ARIMA and LSTM models to forecast Tesla (TSLA) stock prices.
# - The dataset is split chronologically (train: 2015–2023, test: 2024–2025).
# - Models are optimized, evaluated using MAE, RMSE, MAPE, and compared for performance.
#   **Assumptions**:
#    - Data: Adjusted Close prices from `data/TSLA_data.csv` (from Task 1).
#    - Training: July 1, 2015, to December 31, 2023.
#    - Testing: January 1, 2024, to July 31, 2025.
#    - Risk-free rate: 0.02 (not used in forecasting but noted for context).
#     - Outputs saved in `data/output/` and `plots/forecasting/`

# %% [markdown]
# # loading and preparing data
# - splitting into train and test

# %%
from src.time_series_forcasting_models import prepare_data
data_path = 'F:/Time-Series-Forecasting-for-Portfolio-Management-Optimization-/data/scrap data/TSLA_data.csv'
train_data, test_data = prepare_data(data_path)
# Out:
# Training data shape: (2140,)
# Testing data shape: (395,)
# Test data date range: 2024-01-02 00:00:00 to 2025-07-30 00:00:00

# %% [markdown]
# # Fit ARIMA Model or A classical statistical model: ARIMA (AutoRegressive Integrated Moving Average) or SARIMA (Seasonal ARIMA).

# %%
from src.time_series_forcasting_models import fit_arima
arima_forecast, arima_model = fit_arima(train_data,test_data)
# print summary od arima
arima_model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=13644.775, Time=1.76 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=13647.752, Time=0.08 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=13649.026, Time=0.91 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=13649.220, Time=1.37 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=13646.472, Time=0.06 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=13649.127, Time=0.85 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=13648.988, Time=0.46 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=13626.253, Time=6.39 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=13624.409, Time=2.81 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=13624.679, Time=3.89 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=13624.751, Time=4.83 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=13624.619, Time=8.44 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(2,0,0)[12]             : AIC=13622.971, Time=0.79 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(1,0,0)[12]             : AIC=13647.682, Time=0.29 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(2,0,1)[12]             : AIC=13624.822, Time=1.84 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(1,0,1)[12]             : AIC=13643.368, Time=1.62 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,0)(2,0,0)[12]             : AIC=13623.275, Time=1.23 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,1)(2,0,0)[12]             : AIC=13623.346, Time=1.06 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,1)(2,0,0)[12]             : AIC=13623.203, Time=1.97 sec
#
# Best model:  ARIMA(0,1,0)(2,0,0)[12]
# Total fit time: 40.743 seconds
# Length of ARIMA forecast values: 395
# Length of test data index: 395
# First few forecast values: 2140    248.589829
# 2141    249.978745
# 2142    249.734335
# 2143    249.257801
# 2144    249.208264
# dtype: float64
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                 2140
# Model:             SARIMAX(0, 1, 0)x(2, 0, 0, 12)   Log Likelihood               -6808.485
# Date:                            Wed, 13 Aug 2025   AIC                          13622.971
# Time:                                    12:16:26   BIC                          13639.975
# Sample:                                         0   HQIC                         13629.193
#                                            - 2140
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.0174      0.014      1.216      0.224      -0.011       0.046
# ar.S.L24       0.1113      0.012      9.654      0.000       0.089       0.134
# sigma2        34.0567      0.405     84.131      0.000      33.263      34.850
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.73   Jarque-Bera (JB):             11608.23
# Prob(Q):                              0.19   Prob(JB):                         0.00
# Heteroskedasticity (H):             427.69   Skew:                            -0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # A deep learning model: LSTM (Long Short-Term Memory).

# %%
from src.time_series_forcasting_models import fit_lstm
lstm_forecast, lstm_model, scaler = fit_lstm(train_data, test_data)
# to display summary
lstm_model.summary()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - loss: 0.0329 - val_loss: 0.0023
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0015 - val_loss: 9.4314e-04
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0013 - val_loss: 9.6837e-04
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0013 - val_loss: 8.9170e-04
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 0.0011 - val_loss: 8.6511e-04
# Epoch 24/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0013 - val_loss: 7.6250e-04
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0012 - val_loss: 7.1593e-04
# Epoch 27/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0012 - val_loss: 7.2487e-04
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0011 - val_loss: 7.3472e-04
# Epoch 29/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - loss: 0.0010 - val_loss: 8.0492e-04
# Epoch 30/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 0.0012 - val_loss: 7.6494e-04
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 0.0012 - val_loss: 7.4853e-04
# Epoch 32/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 9.8009e-04 - val_loss: 0.0021
# Epoch 33/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0010 - val_loss: 9.7692e-04
# Epoch 34/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0010 - val_loss: 6.2298e-04
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 9.3279e-04 - val_loss: 8.1694e-04
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0010 - val_loss: 7.3832e-04
# Epoch 38/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0010 - val_loss: 6.2334e-04
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 0.0012 - val_loss: 8.4301e-04
# Epoch 40/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 9.5734e-04 - val_loss: 6.0608e-04
# Epoch 41/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0012 - val_loss: 8.0164e-04
# Epoch 42/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.0011 - val_loss: 6.0694e-04
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 9.5419e-04 - val_loss: 5.7151e-04
# Epoch 44/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 8.3562e-04 - val_loss: 5.6964e-04
# Epoch 45/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 9.5641e-04 - val_loss: 8.9405e-04
# Epoch 46/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0011 - val_loss: 5.9598e-04
# Epoch 47/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 9.3363e-04 - val_loss: 5.6662e-04
# Epoch 48/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 9.1837e-04 - val_loss: 5.6341e-04
# Epoch 49/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 9.1276e-04 - val_loss: 0.0012
# Epoch 50/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0010 - val_loss: 6.5901e-04
# LSTM forecast length: 395
# LSTM forecast index: 2024-01-02 00:00:00 to 2025-07-30 00:00:00

# %% [markdown]
# # Model evaluation

# %%
# Model evaluation
from src.time_series_forcasting_models import evaluate_models
metrics_df = evaluate_models(test_data, arima_forecast, lstm_forecast)
# to print summary
metrics_df.head()
# Out:
# Model Performance Comparison:
#    Model         MAE        RMSE       MAPE
# 0   LSTM  178.761717  223.053794  59.882682
# 1  ARIMA   63.036976   77.656542  24.299210
#    Model         MAE        RMSE       MAPE
# 0   LSTM  178.761717  223.053794  59.882682
# 1  ARIMA   63.036976   77.656542  24.299210

# %% [markdown]
#  # Visualization

# %%
# Visualization
from src.time_series_forcasting_models import plot_forecasts
plot_forecasts(train_data, test_data, arima_forecast, lstm_forecast)
